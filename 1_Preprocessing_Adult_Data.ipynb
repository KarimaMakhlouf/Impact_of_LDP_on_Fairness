# %% [markdown]
# ## General imports

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load Adult data reconstructed

# %%
adultData = pd.read_csv('Datasets/adult_reconstruction.csv')

# %%
adultData
# Out:
#        hours-per-week  age  capital-gain  capital-loss         workclass  \
# 0                  20   40             0             0           Private
# 1                  40   21             0             0           Private
# 2                  10   17             0             0           Private
# 3                  50   51             0             0           Private
# 4                  38   28             0             0           Private
# ...               ...  ...           ...           ...               ...
# 49526              65   35             0             0           Private
# 49527              77   37          3137             0  Self-emp-not-inc
# 49528              55   24             0             0           Private
# 49529              40   24             0             0           Private
# 49530              20   39          3464             0         State-gov
#
#           education  education-num      marital-status   relationship  \
# 0         Bachelors             13  Married-civ-spouse           Wife
# 1      Some-college             10            Divorced      Own-child
# 2              11th              7       Never-married      Own-child
# 3           HS-grad              9  Married-civ-spouse        Husband
# 4         Bachelors             13       Never-married  Not-in-family
# ...             ...            ...                 ...            ...
# 49526     Bachelors             13  Married-civ-spouse        Husband
# 49527     Bachelors             13  Married-civ-spouse        Husband
# 49528     Assoc-voc             11       Never-married  Not-in-family
# 49529  Some-college             10       Never-married  Not-in-family
# 49530       HS-grad              9  Married-civ-spouse           Wife
#
#                      race  gender native-country  income       occupation
# 0                   White  Female  United-States   49100     Tech-support
# 1                   White    Male  United-States   11500     Craft-repair
# 2                   White    Male  United-States    2600    Other-service
# 3      Asian-Pac-Islander    Male       Cambodia   38997            Sales
# 4                   White    Male              ?   41400  Exec-managerial
# ...                   ...     ...            ...     ...              ...
# 49526               White    Male     Yugoslavia   85080  Farming-fishing
# 49527  Asian-Pac-Islander    Male        Vietnam   34137            Sales
# 49528               White    Male  United-States   13016            Sales
# 49529               White  Female  United-States   15000     Adm-clerical
# 49530  Asian-Pac-Islander  Female  United-States   29202     Adm-clerical
#
# [49531 rows x 14 columns]

# %% [markdown]
# ## Detecting Missing Values

# %%
adultData.isin(['?']).sum(axis=0)
# Out:
# hours-per-week       0
# age                  0
# capital-gain         0
# capital-loss         0
# workclass         2859
# education            0
# education-num        0
# marital-status       0
# relationship         0
# race                 0
# gender               0
# native-country     859
# income               0
# occupation        2869
# dtype: int64

# %% [markdown]
# ## Cleaning missing data

# %%
adultData['native-country'].replace('?', np.nan, inplace=True)
adultData['workclass'].replace('?', np.nan, inplace=True )
adultData['occupation'].replace('?', np.nan, inplace=True )

#dropping the NaN rows now 
adultData.dropna(how='any', inplace=True)
adultData.reset_index(inplace=True, drop=True)
adultData
# Out:
#        hours-per-week  age  capital-gain  capital-loss         workclass  \
# 0                  20   40             0             0           Private
# 1                  40   21             0             0           Private
# 2                  10   17             0             0           Private
# 3                  50   51             0             0           Private
# 4                  38   26             0          1876           Private
# ...               ...  ...           ...           ...               ...
# 45844              65   35             0             0           Private
# 45845              77   37          3137             0  Self-emp-not-inc
# 45846              55   24             0             0           Private
# 45847              40   24             0             0           Private
# 45848              20   39          3464             0         State-gov
#
#           education  education-num      marital-status   relationship  \
# 0         Bachelors             13  Married-civ-spouse           Wife
# 1      Some-college             10            Divorced      Own-child
# 2              11th              7       Never-married      Own-child
# 3           HS-grad              9  Married-civ-spouse        Husband
# 4         Bachelors             13       Never-married  Not-in-family
# ...             ...            ...                 ...            ...
# 45844     Bachelors             13  Married-civ-spouse        Husband
# 45845     Bachelors             13  Married-civ-spouse        Husband
# 45846     Assoc-voc             11       Never-married  Not-in-family
# 45847  Some-college             10       Never-married  Not-in-family
# 45848       HS-grad              9  Married-civ-spouse           Wife
#
#                      race  gender native-country  income       occupation
# 0                   White  Female  United-States   49100     Tech-support
# 1                   White    Male  United-States   11500     Craft-repair
# 2                   White    Male  United-States    2600    Other-service
# 3      Asian-Pac-Islander    Male       Cambodia   38997            Sales
# 4                   White    Male  United-States   38524  Exec-managerial
# ...                   ...     ...            ...     ...              ...
# 45844               White    Male     Yugoslavia   85080  Farming-fishing
# 45845  Asian-Pac-Islander    Male        Vietnam   34137            Sales
# 45846               White    Male  United-States   13016            Sales
# 45847               White  Female  United-States   15000     Adm-clerical
# 45848  Asian-Pac-Islander  Female  United-States   29202     Adm-clerical
#
# [45849 rows x 14 columns]

# %%
#Renaming some attributes including (hours.per.week, education.num, marital.status and native.country)
adultData.rename(columns={"education-num": "education_num"},inplace=True)
adultData.rename(columns={"hours-per-week": "hoursperweek"},inplace=True)
adultData.rename(columns={"marital-status": "maritalstatus"},inplace=True)
adultData.rename(columns={"native-country": "nativecountry"},inplace=True)

# %%
columns_to_keep = ['age', 'workclass', 'education_num', 'maritalstatus', 'nativecountry', 'hoursperweek', 'gender', 'race', 'income']
adultData = adultData[columns_to_keep]

# %%
# Combine into 'Married' ('Married-civ-spouse', 'Married-spouse-absent','Married-AF-spouse')
adultData.replace(to_replace =["Married-civ-spouse","Married-spouse-absent","Married-AF-spouse"], value ="Married", inplace=True)
# Combine into 'Not_Married' ('Never-marrie', 'Singl','Divorced','Widowed','Separated')
adultData.replace(to_replace =["Never-married","Single","Divorced","Widowed","Separated"], value ="Not_Married", inplace=True)
# Out:
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py:5244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
# binarizing the attributes  
adultData['maritalstatus' ] = adultData['maritalstatus' ].apply( lambda x: 1 if x=='Married' else 0 )
adultData[ 'nativecountry' ] = adultData[ 'nativecountry' ].apply( lambda x: 1 if x=='United-States' else 0 )
adultData ['race'] = adultData ['race'].apply( lambda x: 1 if x == 'White' else 0)
adultData ['gender'] = adultData ['gender'].apply( lambda x: 1 if x == 'Male' else 0)
adultData ['age'] = adultData ['age'].apply( lambda x: 1 if x >= adultData['age'].median() else 0)
adultData ['hoursperweek'] = adultData ['hoursperweek'].apply( lambda x: 1 if x > adultData ['hoursperweek'].median() else 0)
adultData ['education_num'] = adultData ['education_num'].apply( lambda x: 1 if x >= 9  else 0)
adultData['workclass' ] = adultData['workclass' ].apply( lambda x: 1 if x=='Private' else 0 )
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':

# %% [markdown]
# ## Binarizing the target and generating the different datasets

# %%
med = adultData ['income'].median()
adultCopy = adultData.copy()
for th in [10000,int(med),50000]:
    adultData['income'] = adultData['income'].apply(lambda x: 1 if x > th else 0) #float(th) , axis = 1) #label_cutoffs(x,i), axis=1)    
    adultData.to_csv('Datasets/adult_'+ str(th) +'.csv', index=False) 
    adultData ['income'] = adultCopy['income']
# Out:
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
